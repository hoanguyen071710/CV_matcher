# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    # site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor"],
    site_name=["linkedin", "glassdoor"],
    search_term="Data Engineer",
    location="Canada",
    results_wanted=20,
    hours_old=336, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed='Canada',  # only needed for indeed / glassdoor
    
    # linkedin_fetch_description=True # get full description , direct job url , company industry and job level (seniority level) for linkedin (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
    
)
print(f"Found {len(jobs)} jobs")
display(jobs)
# jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2024-08-23 16:32:43,895 - JobSpy - INFO - LinkedIn search page: 1
# 2024-08-23 16:32:44,986 - JobSpy - INFO - Glassdoor search page: 1
# 2024-08-23 16:32:46,572 - JobSpy - INFO - Glassdoor finished scraping
# 2024-08-23 16:32:51,633 - JobSpy - INFO - LinkedIn search page: 2
# 2024-08-23 16:32:52,325 - JobSpy - INFO - Linkedin finished scraping
# Found 40 jobs
#                id       site  \
# 5   1009416536714  glassdoor
# 16  1009417228919  glassdoor
# 19  1009416500311  glassdoor
# 14  1009414939423  glassdoor
# 15  1009414768162  glassdoor
# 0   1009413053876  glassdoor
# 2   1009413056222  glassdoor
# 3   1009413068729  glassdoor
# 4   1009413219399  glassdoor
# 6   1009413462458  glassdoor
# 7   1009413005339  glassdoor
# 9   1009413187101  glassdoor
# 10  1009411657077  glassdoor
# 11  1009411693655  glassdoor
# 1   1009409702156  glassdoor
# 12  1009408825324  glassdoor
# 13  1009409098239  glassdoor
# 8   1009406534180  glassdoor
# 17  1009404336052  glassdoor
# ...

# %%
jobs.columns
# Out:
# Index(['id', 'site', 'job_url', 'job_url_direct', 'title', 'company',
#        'location', 'job_type', 'date_posted', 'salary_source', 'interval',
#        'min_amount', 'max_amount', 'currency', 'is_remote', 'job_level',
#        'job_function', 'company_industry', 'listing_type', 'emails',
#        'description', 'company_url', 'company_url_direct', 'company_addresses',
#        'company_num_employees', 'company_revenue', 'company_description',
#        'logo_photo_url', 'banner_photo_url', 'ceo_name', 'ceo_photo_url'],
#       dtype='object')

# %%
from CV_matcher.model.entities.Job import Job

# %%
# for job in jobs.values:
#     print(job)

models = [Job(**jobAttr) for jobAttr in jobs.to_dict(orient="records")]

print(models[1].job_url)
# Out:
# https://www.glassdoor.ca/job-listing/j?jl=1009414809832

# %%
from CV_matcher.controller.jobScraper.config.Config import Config

# %%
print(Config())
# Out:
# <class 'CV_matcher.controller.jobScraper.config.Config.Config'>
